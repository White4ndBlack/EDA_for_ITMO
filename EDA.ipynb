# %%
import pandas as pd

# %%
data = pd.read_parquet("transaction_fraud_data.parquet")
currency = pd.read_parquet("historical_currency_exchange.parquet")

# %%
data.head()
